# %%
import pandas as pd

# %%
dados = pd.read_csv("State_of_data_2022.csv", sep=",")

# %%
dados.head()
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96                39.0
# 1  zzls2oftfn9law393oezzls2ofhvfpzd                32.0
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi                53.0
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl                27.0
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg                46.0
#
#   ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero') ('P1_c ', 'Cor/raca/etnia')  \
# 0                      35-39           Masculino                       Parda
# 1                      30-34           Masculino                       Parda
# 2                      50-54           Masculino                      Branca
# 3                      25-29           Masculino                      Branca
# 4                      45-49            Feminino                      Branca
#
#   ('P1_d ', 'PCD')  ('P1_e ', 'experiencia_profissional_prejudicada')  \
# 0              Não  Não acredito que minha experiência profissiona...
# ...

# %%
lista = dados.columns.tolist()

divisao = {
    'P0': ('Parte0', 'Identificador'),
    'P1': ('Parte1', 'Dados demográficos'),
    'P2': ('Parte2', 'Dados sobre carreira'),
    'P3': ('Parte3', 'Desafios dos gestores de times de dados'),
    'P4': ('Parte4', 'Conhecimentos na área de dados'),
    'P5': ('Parte5', 'Objetivos na área de dados'),
    'P6': ('Parte6', 'Conhecimentos em Engenharia de Dados/DE'),
    'P7': ('Parte7', 'Conhecimentos em Análise de Dados/DA'),
    'P8': ('Parte8', 'Conhecimentos em Ciências de Dados/DS')
}

# Extrair os dados da lista
dados_extratos = [(item.split("'")[1], item.split("'")[3]) for item in lista]

# Criar DataFrame
descricao = pd.DataFrame(dados_extratos, columns=['IdentificadorQuestao', 'Questao'])

# Adicionar coluna de divisão do questionário
descricao['DivisaoQuestionario'] = descricao['IdentificadorQuestao'].apply(lambda x: divisao.get(x.split('_')[0], ('Outro', 'Outro'))[0])

# Adicionar coluna de identificador
descricao['NomeCategoria'] = descricao['IdentificadorQuestao'].apply(lambda x: divisao.get(x.split('_')[0], ('Outro', 'Outro'))[1])

# Reorganizar colunas
descricao = descricao[['DivisaoQuestionario', 'NomeCategoria', 'IdentificadorQuestao', 'Questao']]

# Exibir o DataFrame
descricao.head()
# Out:
#   DivisaoQuestionario       NomeCategoria IdentificadorQuestao         Questao
# 0              Parte0       Identificador                   P0              id
# 1              Parte1  Dados demográficos                P1_a            Idade
# 2              Parte1  Dados demográficos              P1_a_1      Faixa idade
# 3              Parte1  Dados demográficos                P1_b           Genero
# 4              Parte1  Dados demográficos                P1_c   Cor/raca/etnia

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte1']
categoria
# Out:
#    DivisaoQuestionario       NomeCategoria IdentificadorQuestao  \
# 1               Parte1  Dados demográficos                P1_a
# 2               Parte1  Dados demográficos              P1_a_1
# 3               Parte1  Dados demográficos                P1_b
# 4               Parte1  Dados demográficos                P1_c
# 5               Parte1  Dados demográficos                P1_d
# 6               Parte1  Dados demográficos                P1_e
# 7               Parte1  Dados demográficos                P1_f
# 8               Parte1  Dados demográficos                P1_g
# 9               Parte1  Dados demográficos                P1_i
# 10              Parte1  Dados demográficos              P1_i_1
# 11              Parte1  Dados demográficos              P1_i_2
# 12              Parte1  Dados demográficos                P1_j
# 13              Parte1  Dados demográficos                P1_k
# 14              Parte1  Dados demográficos                P1_l
# ...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte2']
categoria
# Out:
#    DivisaoQuestionario         NomeCategoria IdentificadorQuestao  \
# 16              Parte2  Dados sobre carreira                P2_a
# 17              Parte2  Dados sobre carreira                P2_b
# 18              Parte2  Dados sobre carreira                P2_c
# 19              Parte2  Dados sobre carreira                P2_d
# 20              Parte2  Dados sobre carreira                P2_e
# 21              Parte2  Dados sobre carreira                P2_f
# 22              Parte2  Dados sobre carreira                P2_g
# 23              Parte2  Dados sobre carreira                P2_h
# 24              Parte2  Dados sobre carreira                P2_i
# 25              Parte2  Dados sobre carreira                P2_j
# 26              Parte2  Dados sobre carreira                P2_k
# 27              Parte2  Dados sobre carreira                P2_l
# 28              Parte2  Dados sobre carreira              P2_l_1
# ...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte3']
categoria
# Out:
#    DivisaoQuestionario                            NomeCategoria  \
# 52              Parte3  Desafios dos gestores de times de dados
# 53              Parte3  Desafios dos gestores de times de dados
# 54              Parte3  Desafios dos gestores de times de dados
# 55              Parte3  Desafios dos gestores de times de dados
# 56              Parte3  Desafios dos gestores de times de dados
# 57              Parte3  Desafios dos gestores de times de dados
# 58              Parte3  Desafios dos gestores de times de dados
# 59              Parte3  Desafios dos gestores de times de dados
# 60              Parte3  Desafios dos gestores de times de dados
# 61              Parte3  Desafios dos gestores de times de dados
# 62              Parte3  Desafios dos gestores de times de dados
# 63              Parte3  Desafios dos gestores de times de dados
# 64              Parte3  Desafios dos gestores de times de dados
# 65              Parte3  Desafios dos gestores de times de dados
# ...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte4']
categoria
# Out:
#     DivisaoQuestionario                   NomeCategoria IdentificadorQuestao  \
# 90               Parte4  Conhecimentos na área de dados                P4_a
# 91               Parte4  Conhecimentos na área de dados              P4_a_1
# 92               Parte4  Conhecimentos na área de dados                P4_b
# 93               Parte4  Conhecimentos na área de dados              P4_b_1
# 94               Parte4  Conhecimentos na área de dados              P4_b_2
# ..                  ...                             ...                  ...
# 185              Parte4  Conhecimentos na área de dados             P4_i_19
# 186              Parte4  Conhecimentos na área de dados             P4_i_20
# 187              Parte4  Conhecimentos na área de dados             P4_i_21
# 188              Parte4  Conhecimentos na área de dados             P4_i_22
# 189              Parte4  Conhecimentos na área de dados             P4_i_23
#
#                                                Questao
# ...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte5']
categoria
# Out:
#     DivisaoQuestionario               NomeCategoria IdentificadorQuestao  \
# 190              Parte5  Objetivos na área de dados                P5_a
# 191              Parte5  Objetivos na área de dados                P5_b
# 192              Parte5  Objetivos na área de dados                P5_c
# 193              Parte5  Objetivos na área de dados                P5_d
#
#                                                Questao
# 190                Qual seu objetivo na área de dados?
# 191              Qual oportunidade você está buscando?
# 192  Há quanto tempo você busca uma oportunidade na...
# 193  Como tem sido a busca por um emprego na área d...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte6']
categoria
# Out:
#     DivisaoQuestionario                            NomeCategoria  \
# 194              Parte6  Conhecimentos em Engenharia de Dados/DE
# 195              Parte6  Conhecimentos em Engenharia de Dados/DE
# 196              Parte6  Conhecimentos em Engenharia de Dados/DE
# 197              Parte6  Conhecimentos em Engenharia de Dados/DE
# 198              Parte6  Conhecimentos em Engenharia de Dados/DE
# 199              Parte6  Conhecimentos em Engenharia de Dados/DE
# 200              Parte6  Conhecimentos em Engenharia de Dados/DE
# 201              Parte6  Conhecimentos em Engenharia de Dados/DE
# 202              Parte6  Conhecimentos em Engenharia de Dados/DE
# 203              Parte6  Conhecimentos em Engenharia de Dados/DE
# 204              Parte6  Conhecimentos em Engenharia de Dados/DE
# 205              Parte6  Conhecimentos em Engenharia de Dados/DE
# 206              Parte6  Conhecimentos em Engenharia de Dados/DE
# ...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte7']
categoria
# Out:
#     DivisaoQuestionario                         NomeCategoria  \
# 253              Parte7  Conhecimentos em Análise de Dados/DA
# 254              Parte7  Conhecimentos em Análise de Dados/DA
# 255              Parte7  Conhecimentos em Análise de Dados/DA
# 256              Parte7  Conhecimentos em Análise de Dados/DA
# 257              Parte7  Conhecimentos em Análise de Dados/DA
# 258              Parte7  Conhecimentos em Análise de Dados/DA
# 259              Parte7  Conhecimentos em Análise de Dados/DA
# 260              Parte7  Conhecimentos em Análise de Dados/DA
# 261              Parte7  Conhecimentos em Análise de Dados/DA
# 262              Parte7  Conhecimentos em Análise de Dados/DA
# 263              Parte7  Conhecimentos em Análise de Dados/DA
# 264              Parte7  Conhecimentos em Análise de Dados/DA
# 265              Parte7  Conhecimentos em Análise de Dados/DA
# 266              Parte7  Conhecimentos em Análise de Dados/DA
# ...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte8']
categoria
# Out:
#     DivisaoQuestionario                          NomeCategoria  \
# 303              Parte8  Conhecimentos em Ciências de Dados/DS
# 304              Parte8  Conhecimentos em Ciências de Dados/DS
# 305              Parte8  Conhecimentos em Ciências de Dados/DS
# 306              Parte8  Conhecimentos em Ciências de Dados/DS
# 307              Parte8  Conhecimentos em Ciências de Dados/DS
# 308              Parte8  Conhecimentos em Ciências de Dados/DS
# 309              Parte8  Conhecimentos em Ciências de Dados/DS
# 310              Parte8  Conhecimentos em Ciências de Dados/DS
# 311              Parte8  Conhecimentos em Ciências de Dados/DS
# 312              Parte8  Conhecimentos em Ciências de Dados/DS
# 313              Parte8  Conhecimentos em Ciências de Dados/DS
# 314              Parte8  Conhecimentos em Ciências de Dados/DS
# 315              Parte8  Conhecimentos em Ciências de Dados/DS
# 316              Parte8  Conhecimentos em Ciências de Dados/DS
# ...

# %% [markdown]
# # Fazendo coluna pergunta

# %%
def extrair_pergunta(identificador):
    partes = identificador.split('_')
    if len(partes) > 2:
        return '_'.join(partes[:2])
    else:
        return identificador

# Aplicando a função à coluna "IdentificadorQuestao" para criar a nova coluna "pergunta"
descricao.loc[:, 'pergunta'] = descricao['IdentificadorQuestao'].apply(extrair_pergunta)

# %%
descricao.head()
# Out:
#   DivisaoQuestionario       NomeCategoria IdentificadorQuestao  \
# 0              Parte0       Identificador                   P0
# 1              Parte1  Dados demográficos                P1_a
# 2              Parte1  Dados demográficos              P1_a_1
# 3              Parte1  Dados demográficos                P1_b
# 4              Parte1  Dados demográficos                P1_c
#
#           Questao pergunta
# 0              id       P0
# 1           Idade    P1_a
# 2     Faixa idade     P1_a
# 3          Genero    P1_b
# 4  Cor/raca/etnia    P1_c

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte8']
categoria
# Out:
#     DivisaoQuestionario                          NomeCategoria  \
# 303              Parte8  Conhecimentos em Ciências de Dados/DS
# 304              Parte8  Conhecimentos em Ciências de Dados/DS
# 305              Parte8  Conhecimentos em Ciências de Dados/DS
# 306              Parte8  Conhecimentos em Ciências de Dados/DS
# 307              Parte8  Conhecimentos em Ciências de Dados/DS
# 308              Parte8  Conhecimentos em Ciências de Dados/DS
# 309              Parte8  Conhecimentos em Ciências de Dados/DS
# 310              Parte8  Conhecimentos em Ciências de Dados/DS
# 311              Parte8  Conhecimentos em Ciências de Dados/DS
# 312              Parte8  Conhecimentos em Ciências de Dados/DS
# 313              Parte8  Conhecimentos em Ciências de Dados/DS
# 314              Parte8  Conhecimentos em Ciências de Dados/DS
# 315              Parte8  Conhecimentos em Ciências de Dados/DS
# 316              Parte8  Conhecimentos em Ciências de Dados/DS
# ...

# %% [markdown]
# # Notei um problema aqui

# %%
descricao_filtrada = descricao[descricao['IdentificadorQuestao'].str.len() <= 5]
descricao_filtrada
# Out:
#     DivisaoQuestionario                          NomeCategoria  \
# 0                Parte0                          Identificador
# 1                Parte1                     Dados demográficos
# 3                Parte1                     Dados demográficos
# 4                Parte1                     Dados demográficos
# 5                Parte1                     Dados demográficos
# ..                  ...                                    ...
# 292              Parte7   Conhecimentos em Análise de Dados/DA
# 303              Parte8  Conhecimentos em Ciências de Dados/DS
# 315              Parte8  Conhecimentos em Ciências de Dados/DS
# 329              Parte8  Conhecimentos em Ciências de Dados/DS
# 341              Parte8  Conhecimentos em Ciências de Dados/DS
#
#     IdentificadorQuestao                                            Questao  \
# 0                     P0                                                 id
# ...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte1']
categoria
# Out:
#    DivisaoQuestionario       NomeCategoria IdentificadorQuestao  \
# 1               Parte1  Dados demográficos                P1_a
# 2               Parte1  Dados demográficos              P1_a_1
# 3               Parte1  Dados demográficos                P1_b
# 4               Parte1  Dados demográficos                P1_c
# 5               Parte1  Dados demográficos                P1_d
# 6               Parte1  Dados demográficos                P1_e
# 7               Parte1  Dados demográficos                P1_f
# 8               Parte1  Dados demográficos                P1_g
# 9               Parte1  Dados demográficos                P1_i
# 10              Parte1  Dados demográficos              P1_i_1
# 11              Parte1  Dados demográficos              P1_i_2
# 12              Parte1  Dados demográficos                P1_j
# 13              Parte1  Dados demográficos                P1_k
# 14              Parte1  Dados demográficos                P1_l
# ...

# %%
descricao_filtrada = categoria[categoria['IdentificadorQuestao'].str.len() <= 5]
descricao_filtrada
# Out:
#    DivisaoQuestionario       NomeCategoria IdentificadorQuestao  \
# 1               Parte1  Dados demográficos                P1_a
# 3               Parte1  Dados demográficos                P1_b
# 4               Parte1  Dados demográficos                P1_c
# 5               Parte1  Dados demográficos                P1_d
# 6               Parte1  Dados demográficos                P1_e
# 7               Parte1  Dados demográficos                P1_f
# 8               Parte1  Dados demográficos                P1_g
# 9               Parte1  Dados demográficos                P1_i
# 12              Parte1  Dados demográficos                P1_j
# 13              Parte1  Dados demográficos                P1_k
# 14              Parte1  Dados demográficos                P1_l
# 15              Parte1  Dados demográficos                P1_m
#
#                                  Questao pergunta
# 1                                  Idade    P1_a
# ...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte2']
categoria
# Out:
#    DivisaoQuestionario         NomeCategoria IdentificadorQuestao  \
# 16              Parte2  Dados sobre carreira                P2_a
# 17              Parte2  Dados sobre carreira                P2_b
# 18              Parte2  Dados sobre carreira                P2_c
# 19              Parte2  Dados sobre carreira                P2_d
# 20              Parte2  Dados sobre carreira                P2_e
# 21              Parte2  Dados sobre carreira                P2_f
# 22              Parte2  Dados sobre carreira                P2_g
# 23              Parte2  Dados sobre carreira                P2_h
# 24              Parte2  Dados sobre carreira                P2_i
# 25              Parte2  Dados sobre carreira                P2_j
# 26              Parte2  Dados sobre carreira                P2_k
# 27              Parte2  Dados sobre carreira                P2_l
# 28              Parte2  Dados sobre carreira              P2_l_1
# ...

# %%
descricao_filtrada = categoria[categoria['IdentificadorQuestao'].str.len() <= 5]
descricao_filtrada
# Out:
#    DivisaoQuestionario         NomeCategoria IdentificadorQuestao  \
# 16              Parte2  Dados sobre carreira                P2_a
# 17              Parte2  Dados sobre carreira                P2_b
# 18              Parte2  Dados sobre carreira                P2_c
# 19              Parte2  Dados sobre carreira                P2_d
# 20              Parte2  Dados sobre carreira                P2_e
# 21              Parte2  Dados sobre carreira                P2_f
# 22              Parte2  Dados sobre carreira                P2_g
# 23              Parte2  Dados sobre carreira                P2_h
# 24              Parte2  Dados sobre carreira                P2_i
# 25              Parte2  Dados sobre carreira                P2_j
# 26              Parte2  Dados sobre carreira                P2_k
# 27              Parte2  Dados sobre carreira                P2_l
# 35              Parte2  Dados sobre carreira                P2_m
# ...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte3']
categoria
# Out:
#    DivisaoQuestionario                            NomeCategoria  \
# 52              Parte3  Desafios dos gestores de times de dados
# 53              Parte3  Desafios dos gestores de times de dados
# 54              Parte3  Desafios dos gestores de times de dados
# 55              Parte3  Desafios dos gestores de times de dados
# 56              Parte3  Desafios dos gestores de times de dados
# 57              Parte3  Desafios dos gestores de times de dados
# 58              Parte3  Desafios dos gestores de times de dados
# 59              Parte3  Desafios dos gestores de times de dados
# 60              Parte3  Desafios dos gestores de times de dados
# 61              Parte3  Desafios dos gestores de times de dados
# 62              Parte3  Desafios dos gestores de times de dados
# 63              Parte3  Desafios dos gestores de times de dados
# 64              Parte3  Desafios dos gestores de times de dados
# 65              Parte3  Desafios dos gestores de times de dados
# ...

# %%
descricao_filtrada = categoria[categoria['IdentificadorQuestao'].str.len() <= 5]
descricao_filtrada
# Out:
#    DivisaoQuestionario                            NomeCategoria  \
# 52              Parte3  Desafios dos gestores de times de dados
# 53              Parte3  Desafios dos gestores de times de dados
# 63              Parte3  Desafios dos gestores de times de dados
# 75              Parte3  Desafios dos gestores de times de dados
#
#    IdentificadorQuestao                                            Questao  \
# 52                P3_a   Qual o número aproximado de pessoas que atuam ...
# 53                P3_b   Quais desses papéis/cargos fazem parte do time...
# 63                P3_c   Quais dessas responsabilidades fazem parte da ...
# 75                P3_d   Quais são os 3 maiores desafios que você tem c...
#
#    pergunta
# 52    P3_a
# 53    P3_b
# 63    P3_c
# 75    P3_d

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte4']
categoria
# Out:
#     DivisaoQuestionario                   NomeCategoria IdentificadorQuestao  \
# 90               Parte4  Conhecimentos na área de dados                P4_a
# 91               Parte4  Conhecimentos na área de dados              P4_a_1
# 92               Parte4  Conhecimentos na área de dados                P4_b
# 93               Parte4  Conhecimentos na área de dados              P4_b_1
# 94               Parte4  Conhecimentos na área de dados              P4_b_2
# ..                  ...                             ...                  ...
# 185              Parte4  Conhecimentos na área de dados             P4_i_19
# 186              Parte4  Conhecimentos na área de dados             P4_i_20
# 187              Parte4  Conhecimentos na área de dados             P4_i_21
# 188              Parte4  Conhecimentos na área de dados             P4_i_22
# 189              Parte4  Conhecimentos na área de dados             P4_i_23
#
# ...

# %%
descricao_filtrada = categoria[categoria['IdentificadorQuestao'].str.len() <= 5]
descricao_filtrada
# Out:
#     DivisaoQuestionario                   NomeCategoria IdentificadorQuestao  \
# 90               Parte4  Conhecimentos na área de dados                P4_a
# 92               Parte4  Conhecimentos na área de dados                P4_b
# 101              Parte4  Conhecimentos na área de dados                P4_c
# 110              Parte4  Conhecimentos na área de dados                P4_d
# 125              Parte4  Conhecimentos na área de dados                P4_e
# 126              Parte4  Conhecimentos na área de dados                P4_f
# 127              Parte4  Conhecimentos na área de dados                P4_g
# 161              Parte4  Conhecimentos na área de dados                P4_g
# 162              Parte4  Conhecimentos na área de dados                P4_h
# 166              Parte4  Conhecimentos na área de dados                P4_i
#
#                                                Questao pergunta
# 90   Mesmo que esse não seja seu cargo formal, você...    P4_a
# ...

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte5']
categoria
# Out:
#     DivisaoQuestionario               NomeCategoria IdentificadorQuestao  \
# 190              Parte5  Objetivos na área de dados                P5_a
# 191              Parte5  Objetivos na área de dados                P5_b
# 192              Parte5  Objetivos na área de dados                P5_c
# 193              Parte5  Objetivos na área de dados                P5_d
#
#                                                Questao pergunta
# 190                Qual seu objetivo na área de dados?    P5_a
# 191              Qual oportunidade você está buscando?    P5_b
# 192  Há quanto tempo você busca uma oportunidade na...    P5_c
# 193  Como tem sido a busca por um emprego na área d...    P5_d

# %%
descricao_filtrada = categoria[categoria['IdentificadorQuestao'].str.len() <= 5]
descricao_filtrada
# Out:
#     DivisaoQuestionario               NomeCategoria IdentificadorQuestao  \
# 190              Parte5  Objetivos na área de dados                P5_a
# 191              Parte5  Objetivos na área de dados                P5_b
# 192              Parte5  Objetivos na área de dados                P5_c
# 193              Parte5  Objetivos na área de dados                P5_d
#
#                                                Questao pergunta
# 190                Qual seu objetivo na área de dados?    P5_a
# 191              Qual oportunidade você está buscando?    P5_b
# 192  Há quanto tempo você busca uma oportunidade na...    P5_c
# 193  Como tem sido a busca por um emprego na área d...    P5_d

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte6']
categoria
# Out:
#     DivisaoQuestionario                            NomeCategoria  \
# 194              Parte6  Conhecimentos em Engenharia de Dados/DE
# 195              Parte6  Conhecimentos em Engenharia de Dados/DE
# 196              Parte6  Conhecimentos em Engenharia de Dados/DE
# 197              Parte6  Conhecimentos em Engenharia de Dados/DE
# 198              Parte6  Conhecimentos em Engenharia de Dados/DE
# 199              Parte6  Conhecimentos em Engenharia de Dados/DE
# 200              Parte6  Conhecimentos em Engenharia de Dados/DE
# 201              Parte6  Conhecimentos em Engenharia de Dados/DE
# 202              Parte6  Conhecimentos em Engenharia de Dados/DE
# 203              Parte6  Conhecimentos em Engenharia de Dados/DE
# 204              Parte6  Conhecimentos em Engenharia de Dados/DE
# 205              Parte6  Conhecimentos em Engenharia de Dados/DE
# 206              Parte6  Conhecimentos em Engenharia de Dados/DE
# ...

# %%
descricao_filtrada = categoria[categoria['IdentificadorQuestao'].str.len() <= 5]
descricao_filtrada
# Out:
#     DivisaoQuestionario                            NomeCategoria  \
# 194              Parte6  Conhecimentos em Engenharia de Dados/DE
# 204              Parte6  Conhecimentos em Engenharia de Dados/DE
# 225              Parte6  Conhecimentos em Engenharia de Dados/DE
# 226              Parte6  Conhecimentos em Engenharia de Dados/DE
# 227              Parte6  Conhecimentos em Engenharia de Dados/DE
# 228              Parte6  Conhecimentos em Engenharia de Dados/DE
# 229              Parte6  Conhecimentos em Engenharia de Dados/DE
# 243              Parte6  Conhecimentos em Engenharia de Dados/DE
#
#     IdentificadorQuestao                                            Questao  \
# 194                P6_a   Quais das opções abaixo fazem parte da sua rot...
# 204                P6_b   Quais as ferramentas/tecnologias de ETL que vo...
# 225                P6_c                Sua organização possui um Data Lake?
# ...

# %% [markdown]
# ## Problema na categoria 7
# 253 	Parte7 	Conhecimentos em Análise de Dados/DA 	P7_1 	Quais das opções abaixo fazem parte da sua rot... 	P7_1

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte7']
categoria
# Out:
#     DivisaoQuestionario                         NomeCategoria  \
# 253              Parte7  Conhecimentos em Análise de Dados/DA
# 254              Parte7  Conhecimentos em Análise de Dados/DA
# 255              Parte7  Conhecimentos em Análise de Dados/DA
# 256              Parte7  Conhecimentos em Análise de Dados/DA
# 257              Parte7  Conhecimentos em Análise de Dados/DA
# 258              Parte7  Conhecimentos em Análise de Dados/DA
# 259              Parte7  Conhecimentos em Análise de Dados/DA
# 260              Parte7  Conhecimentos em Análise de Dados/DA
# 261              Parte7  Conhecimentos em Análise de Dados/DA
# 262              Parte7  Conhecimentos em Análise de Dados/DA
# 263              Parte7  Conhecimentos em Análise de Dados/DA
# 264              Parte7  Conhecimentos em Análise de Dados/DA
# 265              Parte7  Conhecimentos em Análise de Dados/DA
# 266              Parte7  Conhecimentos em Análise de Dados/DA
# ...

# %%
descricao_filtrada = categoria[categoria['IdentificadorQuestao'].str.len() <= 5]
descricao_filtrada
# Out:
#     DivisaoQuestionario                         NomeCategoria  \
# 253              Parte7  Conhecimentos em Análise de Dados/DA
# 264              Parte7  Conhecimentos em Análise de Dados/DA
# 285              Parte7  Conhecimentos em Análise de Dados/DA
# 292              Parte7  Conhecimentos em Análise de Dados/DA
#
#     IdentificadorQuestao                                            Questao  \
# 253                P7_1   Quais das opções abaixo fazem parte da sua rot...
# 264                P7_b   Quais as ferramentas/tecnologias de ETL que vo...
# 285                P7_c   Sua empresa utiliza alguma das ferramentas lis...
# 292                P7_d   Em qual das opções abaixo você gasta a maior p...
#
#     pergunta
# 253    P7_1
# 264    P7_b
# 285    P7_c
# 292    P7_d

# %% [markdown]
# ## Problema na categoria 8
# 329 	Parte8 	Conhecimentos em Ciências de Dados/DS 	P8_3 	Quais dessas tecnologias fazem parte do seu di... 	P8_3

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte8']
categoria
# Out:
#     DivisaoQuestionario                          NomeCategoria  \
# 303              Parte8  Conhecimentos em Ciências de Dados/DS
# 304              Parte8  Conhecimentos em Ciências de Dados/DS
# 305              Parte8  Conhecimentos em Ciências de Dados/DS
# 306              Parte8  Conhecimentos em Ciências de Dados/DS
# 307              Parte8  Conhecimentos em Ciências de Dados/DS
# 308              Parte8  Conhecimentos em Ciências de Dados/DS
# 309              Parte8  Conhecimentos em Ciências de Dados/DS
# 310              Parte8  Conhecimentos em Ciências de Dados/DS
# 311              Parte8  Conhecimentos em Ciências de Dados/DS
# 312              Parte8  Conhecimentos em Ciências de Dados/DS
# 313              Parte8  Conhecimentos em Ciências de Dados/DS
# 314              Parte8  Conhecimentos em Ciências de Dados/DS
# 315              Parte8  Conhecimentos em Ciências de Dados/DS
# 316              Parte8  Conhecimentos em Ciências de Dados/DS
# ...

# %%
descricao_filtrada = categoria[categoria['IdentificadorQuestao'].str.len() <= 5]
descricao_filtrada
# Out:
#     DivisaoQuestionario                          NomeCategoria  \
# 303              Parte8  Conhecimentos em Ciências de Dados/DS
# 315              Parte8  Conhecimentos em Ciências de Dados/DS
# 329              Parte8  Conhecimentos em Ciências de Dados/DS
# 341              Parte8  Conhecimentos em Ciências de Dados/DS
#
#     IdentificadorQuestao                                            Questao  \
# 303                P8_a   Quais das opções abaixo fazem parte da sua rot...
# 315                P8_b   Quais as técnicas e métodos listados abaixo vo...
# 329                P8_3   Quais dessas tecnologias fazem parte do seu di...
# 341                P8_d   Em qual das opções abaixo você gasta a maior p...
#
#     pergunta
# 303    P8_a
# 315    P8_b
# 329    P8_3
# 341    P8_d

# %% [markdown]
# ## tratando os problemas

# %%
descricao.loc[descricao['IdentificadorQuestao'] ==  'P7_1 ', 'IdentificadorQuestao'] = "P7_a "

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte7']
categoria
# Out:
#     DivisaoQuestionario                         NomeCategoria  \
# 253              Parte7  Conhecimentos em Análise de Dados/DA
# 254              Parte7  Conhecimentos em Análise de Dados/DA
# 255              Parte7  Conhecimentos em Análise de Dados/DA
# 256              Parte7  Conhecimentos em Análise de Dados/DA
# 257              Parte7  Conhecimentos em Análise de Dados/DA
# 258              Parte7  Conhecimentos em Análise de Dados/DA
# 259              Parte7  Conhecimentos em Análise de Dados/DA
# 260              Parte7  Conhecimentos em Análise de Dados/DA
# 261              Parte7  Conhecimentos em Análise de Dados/DA
# 262              Parte7  Conhecimentos em Análise de Dados/DA
# 263              Parte7  Conhecimentos em Análise de Dados/DA
# 264              Parte7  Conhecimentos em Análise de Dados/DA
# 265              Parte7  Conhecimentos em Análise de Dados/DA
# 266              Parte7  Conhecimentos em Análise de Dados/DA
# ...

# %%
descricao.loc[descricao['IdentificadorQuestao'] ==  'P8_3 ', 'IdentificadorQuestao'] = "P8_c "

# %%
categoria = descricao[descricao.DivisaoQuestionario=='Parte7']
categoria
# Out:
#     DivisaoQuestionario                         NomeCategoria  \
# 253              Parte7  Conhecimentos em Análise de Dados/DA
# 254              Parte7  Conhecimentos em Análise de Dados/DA
# 255              Parte7  Conhecimentos em Análise de Dados/DA
# 256              Parte7  Conhecimentos em Análise de Dados/DA
# 257              Parte7  Conhecimentos em Análise de Dados/DA
# 258              Parte7  Conhecimentos em Análise de Dados/DA
# 259              Parte7  Conhecimentos em Análise de Dados/DA
# 260              Parte7  Conhecimentos em Análise de Dados/DA
# 261              Parte7  Conhecimentos em Análise de Dados/DA
# 262              Parte7  Conhecimentos em Análise de Dados/DA
# 263              Parte7  Conhecimentos em Análise de Dados/DA
# 264              Parte7  Conhecimentos em Análise de Dados/DA
# 265              Parte7  Conhecimentos em Análise de Dados/DA
# 266              Parte7  Conhecimentos em Análise de Dados/DA
# ...

# %% [markdown]
# ## Fazendo nova coluna

# %%
descricao_filtrada = descricao[descricao['IdentificadorQuestao'].str.len() <= 5]
descricao_filtrada
# Out:
#     DivisaoQuestionario                          NomeCategoria  \
# 0                Parte0                          Identificador
# 1                Parte1                     Dados demográficos
# 3                Parte1                     Dados demográficos
# 4                Parte1                     Dados demográficos
# 5                Parte1                     Dados demográficos
# ..                  ...                                    ...
# 292              Parte7   Conhecimentos em Análise de Dados/DA
# 303              Parte8  Conhecimentos em Ciências de Dados/DS
# 315              Parte8  Conhecimentos em Ciências de Dados/DS
# 329              Parte8  Conhecimentos em Ciências de Dados/DS
# 341              Parte8  Conhecimentos em Ciências de Dados/DS
#
#     IdentificadorQuestao                                            Questao  \
# 0                     P0                                                 id
# ...

# %%
dicionario = descricao_filtrada.set_index('pergunta')['Questao'].to_dict()

# %%
dicionario
# Out:
# {'P0': 'id',
#  'P1_a ': 'Idade',
#  'P1_b ': 'Genero',
#  'P1_c ': 'Cor/raca/etnia',
#  'P1_d ': 'PCD',
#  'P1_e ': 'experiencia_profissional_prejudicada',
#  'P1_f ': 'aspectos_prejudicados',
#  'P1_g ': 'vive_no_brasil',
#  'P1_i ': 'Estado onde mora',
#  'P1_j ': 'Mudou de Estado?',
#  'P1_k ': 'Regiao de origem',
#  'P1_l ': 'Nivel de Ensino',
#  'P1_m ': 'Área de Formação',
#  'P2_a ': 'Qual sua situação atual de trabalho?',
#  'P2_b ': 'Setor',
#  'P2_c ': 'Numero de Funcionarios',
#  'P2_d ': 'Gestor?',
#  'P2_e ': 'Cargo como Gestor',
#  'P2_f ': 'Cargo Atual',
#  'P2_g ': 'Nivel',
#  'P2_h ': 'Faixa salarial',
#  'P2_i ': 'Quanto tempo de experiência na área de dados você tem?',
#  'P2_j ': 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#  'P2_k ': 'Você está satisfeito na sua empresa atual?',
#  'P2_l ': 'Qual o principal motivo da sua insatisfação com a empresa atual?',
# ...
